# %% [markdown]
# ## Dynamic Scraping with Selenium and Chrome webdriver

# %% [markdown]
# #### Approx execution time: 1h 30min

# %% [markdown]
# This is a simple notebook to work with Selenium and Chrome Webdriver in order to scrape a dynamic website. While for static websites we can use [Beautiful Soup](https://pypi.org/project/beautifulsoup4/), when we are working with dynamic ones we need Selenium. The key aspect of [Selenium](https://pypi.org/project/selenium/) is that it executes javascript when loading a page request, this allows for dynamic websites to be scraped easily. For the purpose of this exercise we will use [Chrome WebDriver](https://chromedriver.chromium.org/), a tool for automated testing of web apps. To complete our exercise we will also use [pandas](https://pypi.org/project/pandas/), the data science and data analysis library, in order to create a dataframe and export our data to our local machine.
#
# **Tutorial sections:**
# - **Start a Headless session**: Start a WebDriver session with Selenium. It will be headless since we won't open a visual browser window and our script will "drive" it across the pages we need.
# - **One page simple scraping**: retrieve all the content from one page and create a dataframe
# - **Scraping across pages**: Continously load new content, then create a dataframe

# %% [markdown]
# **Step 1: import**

# %%
# Will make scraping possible by importing our webdriver and relevant options. This import section can be easily
#costumized based on your needs (for example to add particular options to your browser or to catch common errors)
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time

# Will allow to request, access and write urls of images and other links
import urllib.request
import requests

# Will allow us to move the data we scrape within tables and then export them to csv
import pandas as pd

# %% [markdown]
# Initialize Selenium and driver instance using Chrome WebDriver. To properly install ChromeDriver you can manually set the path following [this guide](https://www.kenst.com/2015/03/including-the-chromedriver-location-in-macos-system-path/) or use `pip install webdriver-manager` to manage it.

# %% [markdown]
# **Step 2: start Chrome webdriver session**

# %% [markdown]
# For the purpose of this exercise we will get some movies from [Rotten Tomatoes](https://www.rottentomatoes.com/browse/dvd-streaming-all). We are interested in creating a dataset of titles with their ranking, date of release and cover.

# %%
# We start an headless Chrome session. (Headless means that we don't open a visual browser window)
options = Options()
#If you comment out this option below you will be able to see Chrome opening and performing operations!
options.headless = True
options.add_argument("--window-size=1920,1200")
options.add_argument("--disable-gpu");

# instead of setting path manually (still possible but a bit annoying) we use DriverManager
driver = webdriver.Chrome(executable_path=ChromeDriverManager().install(), options=options)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Seb\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# C:\Users\Seb\AppData\Local\Temp/ipykernel_40624/3795137898.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=ChromeDriverManager().install(), options=options)

# %%
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2000-01-01,2021-12-31&sort=num_votes,desc&count=250")

# print(driver.page_source)
# remove the comment above to print the result of our driver.get()
print('done')
# Out:
# done

# %% [markdown]
# ### One time simple scraping

# %% [markdown]
# The concept behind scraping is quite easy to grasp. We are creating a script that behaves like a human. By using the correct methods we can fake human interactions on webpage. While usually scripts "see" different things than us, Selenium, Beautiful Soup and WebDrivers are built to see pages as we would do. Scripts are obviously faster, they don't get to go to the toilet and they do everything very enthusiastically.

# %% [markdown]
# **Step 3: Get movies**

# %% [markdown]
# Now we will select specific elements we are interested in. To do so we can instruct our script to look for them on the page. Selenium provides a series of methods to do so: we can select elements according to their class name, html tag, css selector, attribute and so on. Please go to https://www.rottentomatoes.com/browse/dvd-streaming-all, right-click on any part of the screen and then select "Inspect Element" to activate the source inspector. Here you can check the page structure and select the elements you want to obtain. In our case each movie preview is wrapper in a container with class `mb-movie`. To get all the movies we will tell Selenium to collect only elements with this specific class name.

# %%
# Only getting first page results
movies = driver.find_elements(By.CLASS_NAME, 'lister-item-content')
# Check how many elements we obtained. It should be 32, the number of results for the first page.
print(len(movies))
# Out:
# 250

# %% [markdown]
# **Step 4: loop through movies and build a list of lists containing our data**

# %% [markdown]
# Now that we have a list of elements we can loop over it and replicate our pattern in a more structured way. We will ask Selenium to look for text and images of movies. Again we have a wide range of opportunities. We can use the `.text` method to obtain the content of an HTML tag or we can get attributes from links, it really depends on the website structure and the information we are interested in.

# %%
# This empty list will later contain my precious data
moviesData = []
# I am creating a counter, this will print the parser status and generate filenames for images
count = 0
for movie in movies:
    
    count = count + 1
    
    # we can get precise elements by using css selectors, classes, tag names and xpaths
    title = movie.find_element(By.CLASS_NAME, 'lister-item-header').find_element(By.TAG_NAME, "a").text
    length = movie.find_element(By.CLASS_NAME, 'runtime').text
    rating = movie.find_element(By.CLASS_NAME, 'ratings-imdb-rating').find_element(By.TAG_NAME, "strong").text
    metascore_elements = movie.find_elements(By.CLASS_NAME, 'metascore')
    if len(metascore_elements) > 0:
        metascore = metascore_elements[0].text
    values = movie.find_element(By.CLASS_NAME, 'sort-num_votes-visible').find_elements(By.NAME, 'nv')
    number_votes = values[0].get_attribute("data-value")
    if len(values) > 1:
        gross = "".join(values[1].get_attribute("data-value").split(","))
    else:
        gross = 'none'
    available = movie.find_element(By.CLASS_NAME, 'lister-item-year').text
    print(count, '/', title, length, available, rating, metascore, number_votes, gross)
    
    # it is also possible to get accessory information from collected elements, 
    # in this case we want to get the url of the poster images, we can retrieve it from the src attribute
    
    # We use urllib to read the poster images and save them locally in a special folder. In order to avoid
    # overwriting we use the {0}.format('dynamic variable') to save all of them
    
    # We append a shorter list to the initial list
    moviesData.append([title, length, available, rating, metascore, number_votes, gross])

# Safety print to check everything is fine!
print(moviesData)
# Out:
# 1 / The Dark Knight 152 min (2008) 9.0 84 2470523 534858444
# 2 / Inception 148 min (2010) 8.8 74 2215371 292576195
# 3 / The Lord of the Rings: The Fellowship of the Ring 178 min (2001) 8.8 92 1761021 315544750
# 4 / The Lord of the Rings: The Return of the King 201 min (2003) 8.9 94 1739914 377845905
# 5 / Interstellar 169 min (2014) 8.6 74 1666627 188020017
# 6 / The Dark Knight Rises 164 min (2012) 8.4 78 1605164 448139099
# 7 / The Lord of the Rings: The Two Towers 179 min (2002) 8.7 87 1572339 342551365
# 8 / Django Unchained 165 min (2012) 8.4 81 1457235 162805434
# 9 / Gladiator 155 min (2000) 8.5 67 1424037 187705427
# 10 / Batman Begins 140 min (2005) 8.2 70 1382202 206852432
# 11 / Inglourious Basterds 153 min (2009) 8.3 69 1359864 120540719
# 12 / Avengers Assemble 143 min (2012) 8.0 69 1329338 623279547
# 13 / The Wolf of Wall Street 180 min (2013) 8.2 75 1298667 116900694
# 14 / The Prestige 130 min (2006) 8.5 66 1266860 53089891
# 15 / The Departed 151 min (2006) 8.5 85 1260855 132384315
# 16 / Shutter Island 138 min (2010) 8.2 63 1223814 128012934
# 17 / Memento 113 min (2000) 8.4 80 1185698 25544867
# 18 / Avatar 162 min (2009) 7.8 83 1172346 760507625
# 19 / Joker 122 min (2019) 8.4 59 1122039 335451311
# 20 / Guardians of the Galaxy 121 min (2014) 8.0 76 1115031 333176600
# 21 / V for Vendetta 132 min (2005) 8.1 62 1082186 70511035
# 22 / Kill Bill: Vol. 1 111 min (2003) 8.1 69 1063206 70099045
# 23 / WALL·E 98 min (2008) 8.4 95 1060010 223808164
# 24 / Pirates of the Caribbean: The Curse of the Black Pearl 143 min (2003) 8.0 63 1057221 305413918
# 25 / Iron Man 126 min (2008) 7.9 79 1004199 318412101
# 26 / Finding Nemo 100 min (2003) 8.1 90 998164 380843261
# 27 / Up 96 min (2009) 8.2 88 991938 293004164
# 28 / Avengers: Endgame 181 min (2019) 8.4 78 988758 858373000
# 29 / Deadpool 108 min (2016) 8.0 65 970244 363070709
# 30 / Avengers: Infinity War 149 min (2018) 8.4 68 963362 678815482
# 31 / Eternal Sunshine of the Spotless Mind 108 min (2004) 8.3 89 962016 34400301
# 32 / Mad Max: Fury Road 120 min (2015) 8.1 90 946049 154058340
# 33 / Gone Girl 149 min (2014) 8.1 79 927795 167767189
# 34 / No Country for Old Men 122 min (2007) 8.1 91 919192 74283625
# 35 / Catch Me If You Can 141 min (2002) 8.1 75 909961 164615351
# 36 / Star Wars: Episode VII - The Force Awakens 138 min (2015) 7.8 80 895586 936662225
# 37 / A Beautiful Mind 135 min (2001) 8.2 72 893954 170742341
# 38 / The Hunger Games 142 min (2012) 7.2 68 884662 408010692
# 39 / Monsters, Inc. 92 min (2001) 8.1 79 864655 289916256
# 40 / Slumdog Millionaire 120 min (2008) 8.0 84 824630 141319928
# 41 / Snatch 104 min (2000) 8.2 55 822902 30328156
# 42 / Harry Potter and the Deathly Hallows: Part 2 130 min (2011) 8.1 85 821349 381011219
# 43 / Untouchable 112 min (2011) 8.5 57 812031 13182281
# 44 / The Martian 144 min (2015) 8.0 80 810485 228433663
# 45 / Avengers: Age of Ultron 141 min (2015) 7.3 66 810208 459005868
# 46 / Iron Man 3 130 min (2013) 7.1 62 807292 409013994
# 47 / Requiem for a Dream 102 min (2000) 8.3 68 805854 3635482
# 48 / Gravity 91 min (2013) 7.7 96 800774 274092705
# 49 / Captain America: The First Avenger 124 min (2011) 6.9 66 799864 176654505
# 50 / Thor 115 min (2011) 7.0 57 799546 181030624
# 51 / Toy Story 3 103 min (2010) 8.2 92 797818 415004880
# 52 / Captain America: The Winter Soldier 136 min (2014) 7.7 70 795338 259766572
# 53 / The Hobbit: An Unexpected Journey 169 min (2012) 7.8 58 791137 303003568
# 54 / The Pianist 150 min (2002) 8.5 85 785789 32572577
# 55 / Whiplash 106 min (2014) 8.5 88 782297 13092000
# 56 / Iron Man 2 124 min (2010) 7.0 57 774649 312433331
# 57 / Donnie Darko 113 min (2001) 8.0 88 772493 1480006
# 58 / Spider-Man 121 min (2002) 7.3 73 765353 403706375
# 59 / 300 117 min (2006) 7.6 52 764952 210614939
# 60 / The Grand Budapest Hotel 99 min (2014) 8.1 88 761885 59100318
# 61 / The Revenant 156 min (2015) 8.0 76 758768 183637894
# 62 / Sin City 124 min (2005) 8.0 74 754263 74103820
# 63 / The Hangover 100 min (2009) 7.7 73 753225 277322503
# 64 / Gran Torino 116 min (2008) 8.1 72 750771 148095302
# 65 / Star Wars: Episode III - Revenge of the Sith 140 min (2005) 7.5 68 748286 380262555
# 66 / Man of Steel 143 min (2013) 7.0 55 739536 291045518
# 67 / Black Swan 108 min (2010) 8.0 79 733743 106954678
# 68 / Amélie 122 min (2001) 8.3 69 732713 33225499
# 69 / The Imitation Game 114 min (2014) 8.0 71 731069 91125683
# 70 / City of God 130 min (2002) 8.6 79 730439 7563397
# 71 / Captain America: Civil War 147 min (2016) 7.8 75 729622 408084349
# 72 / Harry Potter and the Philosopher's Stone 152 min (2001) 7.6 65 726348 317575550
# 73 / Kill Bill: Vol. 2 137 min (2004) 8.0 83 724456 66208183
# 74 / I Am Legend 101 min (2007) 7.2 65 724035 256386216
# 75 / Spirited Away 125 min (2001) 8.6 96 710303 10055859
# 76 / Logan 137 min (2017) 8.1 77 705697 226277068
# 77 / How to Train Your Dragon 98 min (2010) 8.1 75 704542 217581231
# 78 / Parasite 132 min (2019) 8.6 96 701491 53367844
# 79 / Black Panther 134 min (2018) 7.3 88 697616 700059566
# 80 / The Incredibles 115 min (2004) 8.0 90 691033 261441092
# 81 / Silver Linings Playbook 122 min (2012) 7.7 81 688403 132092958
# 82 / X-Men: Days of Future Past 132 min (2014) 7.9 75 687307 233921534
# 83 / Pirates of the Caribbean: Dead Man's Chest 151 min (2006) 7.3 53 684648 423315812
# 84 / Ratatouille 111 min (2007) 8.0 96 681096 206445654
# 85 / Star Wars: Episode II - Attack of the Clones 142 min (2002) 6.5 54 675322 310675583
# 86 / Skyfall 143 min (2012) 7.8 81 675231 304360277
# 87 / 12 Years a Slave 134 min (2013) 8.1 96 673618 56671993
# 88 / Batman v Superman: Dawn of Justice 152 min (2016) 6.4 44 672878 330360194
# 89 / X-Men: First Class 131 min (2011) 7.7 65 670060 146408305
# 90 / Thor: Ragnarok 130 min (2017) 7.9 74 669997 315058289
# 91 / Inside Out 95 min (I) (2015) 8.1 94 668109 356461711
# 92 / Doctor Strange 115 min (2016) 7.5 72 667916 232641920
# 93 / The Social Network 120 min (2010) 7.7 95 667036 96962694
# 94 / Million Dollar Baby 132 min (2004) 8.1 86 665308 100492203
# 95 / The King's Speech 118 min (2010) 8.0 88 662623 138797449
# 96 / District 9 112 min (2009) 7.9 81 662022 115646235
# 97 / Suicide Squad 123 min (2016) 5.9 40 660903 325100054
# 98 / Once Upon a Time... In Hollywood 161 min (2019) 7.6 83 660474 142502728
# 99 / Prisoners 153 min (2013) 8.1 70 655653 61002302
# 100 / Arrival 116 min (II) (2016) 7.9 81 654308 100546139
# 101 / Shrek 90 min (2001) 7.9 84 647299 267665011
# 102 / Pan's Labyrinth 118 min (2006) 8.2 98 646386 37634615
# 103 / Edge of Tomorrow 113 min (2014) 7.9 71 642474 100206256
# 104 / Thor: The Dark World 112 min (2013) 6.8 54 642131 206362140
# 105 / The Hunger Games: Catching Fire 146 min (2013) 7.5 76 641382 424668047
# 106 / World War Z 116 min (2013) 7.0 63 635749 202359711
# 107 / Casino Royale 144 min (2006) 8.0 80 633900 167445960
# 108 / The Hobbit: The Desolation of Smaug 161 min (2013) 7.8 66 631400 258366855
# 109 / Now You See Me 115 min (I) (2013) 7.2 50 630150 117723989
# 110 / Kingsman: The Secret Service 129 min (2014) 7.7 60 629222 128261724
# 111 / Guardians of the Galaxy: Vol. 2 136 min (2017) 7.6 67 628632 389813101
# 112 / The Curious Case of Benjamin Button 166 min (2008) 7.8 70 623380 127509326
# 113 / Ant-Man 117 min (2015) 7.3 64 623289 180202163
# 114 / Wonder Woman 141 min (2017) 7.4 76 622589 412563408
# 115 / Pirates of the Caribbean: At World's End 169 min (2007) 7.1 50 622339 309420425
# 116 / The Bourne Ultimatum 115 min (2007) 8.0 85 621310 227471070
# 117 / Transformers 144 min (2007) 7.0 61 619168 319246193
# 118 / The Amazing Spider-Man 136 min (2012) 6.9 66 614226 262030663
# 119 / Dunkirk 106 min (2017) 7.8 94 611645 188373161
# 120 / Sherlock Holmes 128 min (2009) 7.6 57 610711 209028679
# 121 / Spider-Man 2 127 min (2004) 7.4 83 609519 373585825
# 122 / Jurassic World 124 min (2015) 7.0 59 609356 652270625
# 123 / Birdman or (The Unexpected Virtue of Ignorance) 119 min (2014) 7.7 87 608477 42340598
# 124 / Life of Pi 127 min (2012) 7.9 79 607532 124987023
# 125 / Drive 100 min (I) (2011) 7.8 78 604991 35061555
# 126 / Into the Wild 148 min (2007) 8.1 73 602391 18354356
# 127 / Frozen 102 min (I) (2013) 7.4 75 600615 400738009
# 128 / Star Wars: Episode VIII - The Last Jedi 152 min (2017) 6.9 84 598955 620181382
# 129 / Harry Potter and the Chamber of Secrets 161 min (2002) 7.4 63 597557 261988482
# 130 / Argo 120 min (2012) 7.7 86 597162 136025503
# 131 / Harry Potter and the Prisoner of Azkaban 142 min (2004) 7.9 82 595797 249358727
# 132 / X-Men 104 min (2000) 7.4 64 594514 157299717
# 133 / Star Trek 127 min (2009) 7.9 82 593843 257730019
# 134 / Spider-Man: Homecoming 133 min (2017) 7.4 73 593061 334201140
# 135 / Ted 106 min (2012) 6.9 62 592867 218815487
# 136 / John Wick 101 min (2014) 7.4 68 591332 43037835
# 137 / Prometheus 124 min (I) (2012) 7.0 64 591135 126477084
# 138 / Rogue One 133 min (2016) 7.8 65 591126 532177324
# 139 / Harry Potter and the Goblet of Fire 157 min (2005) 7.7 81 589154 290013036
# 140 / Taken 90 min (I) (2008) 7.8 51 586254 145000989
# 141 / Her 126 min (2013) 8.0 91 577955 25568251
# 142 / The Matrix Reloaded 138 min (2003) 7.2 62 569802 281492479
# 143 / Cast Away 143 min (2000) 7.8 73 563608 233632142
# 144 / The Hateful Eight 168 min (2015) 7.8 68 563544 54117416
# 145 / Knives Out 130 min (2019) 7.9 82 562659 165359751
# 146 / Looper 113 min (2012) 7.4 84 558665 66486205
# 147 / There Will Be Blood 158 min (2007) 8.2 93 555435 40222514
# 148 / Spider-Man 3 139 min (2007) 6.2 59 552751 336530303
# 149 / Limitless 105 min (I) (2011) 7.4 59 551909 79249455
# 150 / Superbad 113 min (2007) 7.6 76 551597 121463226
# 151 / Oldboy 120 min (2003) 8.4 77 550628 707481
# 152 / Zombieland 88 min (2009) 7.6 73 550267 75590286
# 153 / La La Land 128 min (2016) 8.0 94 550221 151101803
# 154 / The Notebook 123 min (2004) 7.8 53 548510 81001787
# 155 / Harry Potter and the Order of the Phoenix 138 min (2007) 7.5 71 548343 292004738
# 156 / Ocean's Eleven 116 min (2001) 7.7 74 547495 183417150
# 157 / Kick-Ass 117 min (2010) 7.6 66 545166 48071303
# 158 / Get Out 104 min (I) (2017) 7.7 85 544113 176040665
# 159 / American Psycho 101 min (2000) 7.6 64 541530 15070285
# 160 / Shaun of the Dead 99 min (2004) 7.9 76 538049 13542874
# 161 / 21 Jump Street 109 min (2012) 7.2 69 536988 138447667
# 162 / Deadpool 2 119 min (2018) 7.7 66 534470 324591735
# 163 / Minority Report 145 min (2002) 7.6 80 533013 132072926
# 164 / X-Men 2 134 min (2003) 7.4 68 532877 214949694
# 165 / Watchmen 162 min (2009) 7.6 56 531781 107509799
# 166 / The Bourne Identity 119 min (2002) 7.9 68 530803 121661683
# 167 / Blood Diamond 143 min (2006) 8.0 64 526954 57366262
# 168 / Despicable Me 95 min (2010) 7.6 72 523975 251513985
# 169 / Blade Runner 2049 164 min (2017) 8.0 81 522427 92054159
# 170 / I, Robot 115 min (2004) 7.1 59 521747 144801023
# 171 / 1917 119 min (2019) 8.3 78 520580 159227644
# 172 / Harry Potter and the Deathly Hallows: Part 1 146 min (2010) 7.7 65 515899 295983305
# 173 / The Great Gatsby 143 min (2013) 7.2 55 514211 144840419
# 174 / Troy 163 min (2004) 7.3 56 513614 133378256
# 175 / Rise of the Planet of the Apes 105 min (2011) 7.5 68 513058 176760185
# 176 / Ex Machina 108 min (2014) 7.7 78 512907 25442958
# 177 / Harry Potter and the Half-Blood Prince 153 min (2009) 7.6 78 512622 301959197
# 178 / Captain Marvel 123 min (2019) 6.8 64 510925 426829839
# 179 / Zodiac 157 min (2007) 7.7 78 509275 33080084
# 180 / Juno 96 min (2007) 7.4 81 507727 143495265
# 181 / Nightcrawler 117 min (2014) 7.8 76 507603 32381218
# 182 / Oblivion 124 min (I) (2013) 7.0 54 507177 89021735
# 183 / Source Code 93 min (2011) 7.5 74 505239 54712227
# 184 / Pirates of the Caribbean: On Stranger Tides 137 min (2011) 6.6 45 504341 241063875
# 185 / It 135 min (I) (2017) 7.3 69 503935 327481748
# 186 / The Hobbit: The Battle of the Five Armies 144 min (2014) 7.4 59 503084 255119788
# 187 / Bohemian Rhapsody 134 min (2018) 7.9 49 501625 216428042
# 188 / X-Men: The Last Stand 104 min (2006) 6.7 58 501358 234362462
# 189 / Crazy, Stupid, Love. 118 min (2011) 7.4 68 499736 84351197
# 190 / 500 Days of Summer 95 min (2009) 7.6 76 494424 32391374
# 191 / Baby Driver 113 min (2017) 7.6 86 492936 107825862
# 192 / A Quiet Place 90 min (2018) 7.5 82 492690 188024361
# 193 / The Matrix Revolutions 129 min (2003) 6.8 47 491705 139313948
# 194 / The Perks of Being a Wallflower 103 min (2012) 7.9 67 488963 17742948
# 195 / Hot Fuzz 121 min (2007) 7.8 81 488450 23637265
# 196 / X-Men Origins: Wolverine 107 min (2009) 6.6 40 487672 179883157
# 197 / Children of Men 109 min (2006) 7.9 84 485549 35552383
# 198 / Pacific Rim 131 min (2013) 6.9 65 485417 101802906
# 199 / The Hangover Part II 102 min (2011) 6.5 44 483349 254464305
# 200 / The Pursuit of Happyness 117 min (2006) 8.0 64 483174 163566459
# 201 / The Conjuring 112 min (2013) 7.5 68 482405 137400141
# 202 / Hacksaw Ridge 139 min (2016) 8.1 71 482179 67209615
# 203 / Three Billboards Outside Ebbing, Missouri 115 min (2017) 8.1 88 477020 54513740
# 204 / Star Trek Into Darkness 132 min (2013) 7.7 72 475593 228778661
# 205 / Mr. & Mrs. Smith 120 min (2005) 6.5 55 475045 186336279
# 206 / Mission: Impossible - Ghost Protocol 132 min (2011) 7.4 73 474768 209397903
# 207 / Lucy 89 min (I) (2014) 6.4 61 474208 126663600
# 208 / The Butterfly Effect 113 min (2004) 7.6 30 472678 57938693
# 209 / Dallas Buyers Club 117 min (2013) 8.0 79 468725 27298285
# 210 / Love Actually 135 min (2003) 7.6 55 468215 59696144
# 211 / Zootropolis 108 min (2016) 8.0 78 468094 341268248
# 212 / American Hustle 138 min (2013) 7.2 90 466778 150117807
# 213 / The Incredible Hulk 112 min (2008) 6.6 61 465653 134518390
# 214 / Hancock 92 min (2008) 6.4 49 465365 227946274
# 215 / American Sniper 133 min (2014) 7.3 72 464760 350126372
# 216 / Split 117 min (IX) (2016) 7.3 62 464383 138291365
# 217 / Ice Age 81 min (2002) 7.5 61 464162 176387405
# 218 / The Amazing Spider-Man 2 142 min (2014) 6.6 53 463284 202853933
# 219 / Little Miss Sunshine 101 min (2006) 7.8 80 460565 59891098
# 220 / Rush 123 min (I) (2013) 8.1 74 459752 26947624
# 221 / Fury 134 min (2014) 7.6 64 459515 85817906
# 222 / Spider-Man: Into the Spider-Verse 117 min (2018) 8.4 87 457481 190241310
# 223 / Charlie and the Chocolate Factory 115 min (2005) 6.6 72 455832 206459076
# 224 / Warrior 140 min (2011) 8.1 71 455140 13657115
# 225 / Coco 105 min (I) (2017) 8.4 81 451666 209726015
# 226 / The Bourne Supremacy 108 min (2004) 7.7 73 451457 176241941
# 227 / Spotlight 129 min (I) (2015) 8.1 93 450100 45055776
# 228 / The Wolverine 126 min (2013) 6.7 61 449428 132556852
# 229 / Twilight 122 min (I) (2008) 5.2 56 447849 191465414
# 230 / The Girl with the Dragon Tattoo 158 min (2011) 7.8 71 447570 102515793
# 231 / Kung Fu Panda 92 min (2008) 7.6 74 445518 215434591
# 232 / Tenet 150 min (2020) 7.4 69 445414 58456624
# 233 / Venom 112 min (2018) 6.7 35 445366 213515506
# 234 / Divergent 139 min (2014) 6.6 48 444763 150947895
# 235 / The Maze Runner 113 min (2014) 6.8 57 444450 102427862
# 236 / Captain Phillips 134 min (2013) 7.8 82 443368 107100855
# 237 / The Help 146 min (2011) 8.0 62 443100 169708112
# 238 / Shrek 2 93 min (2004) 7.2 75 442900 436471036
# 239 / Green Book 130 min (2018) 8.2 69 442751 85080171
# 240 / Mystic River 138 min (2003) 7.9 84 442620 90135191
# 241 / Indiana Jones and the Kingdom of the Crystal Skull 122 min (2008) 6.1 65 442455 317101119
# 242 / Sherlock Holmes: A Game of Shadows 129 min (2011) 7.5 48 439553 186848418
# 243 / The Hurt Locker 131 min (2008) 7.5 95 438948 17017811
# 244 / Lost in Translation 102 min (2003) 7.7 89 438582 44585453
# 245 / Fantastic Beasts and Where to Find Them 132 min (2016) 7.3 66 438031 234037575
# 246 / Big Hero 6 102 min (2014) 7.8 74 437293 222527828
# 247 / The Hunger Games: Mockingjay - Part 1 123 min (2014) 6.6 64 437168 337135885
# 248 / The Terminal 128 min (2004) 7.4 55 437124 77872883
# 249 / Horrible Bosses 98 min (2011) 6.8 57 436656 117538559
# 250 / Elysium 109 min (I) (2013) 6.6 61 435936 93050117
# [['The Dark Knight', '152 min', '(2008)', '9.0', '84', '2470523', '534858444'], ['Inception', '148 min', '(2010)', '8.8', '74', '2215371', '292576195'], ['The Lord of the Rings: The Fellowship of the Ring', '178 min', '(2001)', '8.8', '92', '1761021', '315544750'], ['The Lord of the Rings: The Return of the King', '201 min', '(2003)', '8.9', '94', '1739914', '377845905'], ['Interstellar', '169 min', '(2014)', '8.6', '74', '1666627', '188020017'], ['The Dark Knight Rises', '164 min', '(2012)', '8.4', '78', '1605164', '448139099'], ['The Lord of the Rings: The Two Towers', '179 min', '(2002)', '8.7', '87', '1572339', '342551365'], ['Django Unchained', '165 min', '(2012)', '8.4', '81', '1457235', '162805434'], ['Gladiator', '155 min', '(2000)', '8.5', '67', '1424037', '187705427'], ['Batman Begins', '140 min', '(2005)', '8.2', '70', '1382202', '206852432'], ['Inglourious Basterds', '153 min', '(2009)', '8.3', '69', '1359864', '120540719'], ['Avengers Assemble', '143 min', '(2012)', '8.0', '69', '1329338', '623279547'], ['The Wolf of Wall Street', '180 min', '(2013)', '8.2', '75', '1298667', '116900694'], ['The Prestige', '130 min', '(2006)', '8.5', '66', '1266860', '53089891'], ['The Departed', '151 min', '(2006)', '8.5', '85', '1260855', '132384315'], ['Shutter Island', '138 min', '(2010)', '8.2', '63', '1223814', '128012934'], ['Memento', '113 min', '(2000)', '8.4', '80', '1185698', '25544867'], ['Avatar', '162 min', '(2009)', '7.8', '83', '1172346', '760507625'], ['Joker', '122 min', '(2019)', '8.4', '59', '1122039', '335451311'], ['Guardians of the Galaxy', '121 min', '(2014)', '8.0', '76', '1115031', '333176600'], ['V for Vendetta', '132 min', '(2005)', '8.1', '62', '1082186', '70511035'], ['Kill Bill: Vol. 1', '111 min', '(2003)', '8.1', '69', '1063206', '70099045'], ['WALL·E', '98 min', '(2008)', '8.4', '95', '1060010', '223808164'], ['Pirates of the Caribbean: The Curse of the Black Pearl', '143 min', '(2003)', '8.0', '63', '1057221', '305413918'], ['Iron Man', '126 min', '(2008)', '7.9', '79', '1004199', '318412101'], ['Finding Nemo', '100 min', '(2003)', '8.1', '90', '998164', '380843261'], ['Up', '96 min', '(2009)', '8.2', '88', '991938', '293004164'], ['Avengers: Endgame', '181 min', '(2019)', '8.4', '78', '988758', '858373000'], ['Deadpool', '108 min', '(2016)', '8.0', '65', '970244', '363070709'], ['Avengers: Infinity War', '149 min', '(2018)', '8.4', '68', '963362', '678815482'], ['Eternal Sunshine of the Spotless Mind', '108 min', '(2004)', '8.3', '89', '962016', '34400301'], ['Mad Max: Fury Road', '120 min', '(2015)', '8.1', '90', '946049', '154058340'], ['Gone Girl', '149 min', '(2014)', '8.1', '79', '927795', '167767189'], ['No Country for Old Men', '122 min', '(2007)', '8.1', '91', '919192', '74283625'], ['Catch Me If You Can', '141 min', '(2002)', '8.1', '75', '909961', '164615351'], ['Star Wars: Episode VII - The Force Awakens', '138 min', '(2015)', '7.8', '80', '895586', '936662225'], ['A Beautiful Mind', '135 min', '(2001)', '8.2', '72', '893954', '170742341'], ['The Hunger Games', '142 min', '(2012)', '7.2', '68', '884662', '408010692'], ['Monsters, Inc.', '92 min', '(2001)', '8.1', '79', '864655', '289916256'], ['Slumdog Millionaire', '120 min', '(2008)', '8.0', '84', '824630', '141319928'], ['Snatch', '104 min', '(2000)', '8.2', '55', '822902', '30328156'], ['Harry Potter and the Deathly Hallows: Part 2', '130 min', '(2011)', '8.1', '85', '821349', '381011219'], ['Untouchable', '112 min', '(2011)', '8.5', '57', '812031', '13182281'], ['The Martian', '144 min', '(2015)', '8.0', '80', '810485', '228433663'], ['Avengers: Age of Ultron', '141 min', '(2015)', '7.3', '66', '810208', '459005868'], ['Iron Man 3', '130 min', '(2013)', '7.1', '62', '807292', '409013994'], ['Requiem for a Dream', '102 min', '(2000)', '8.3', '68', '805854', '3635482'], ['Gravity', '91 min', '(2013)', '7.7', '96', '800774', '274092705'], ['Captain America: The First Avenger', '124 min', '(2011)', '6.9', '66', '799864', '176654505'], ...

# %% [markdown]
# **Step 5: Move list of lists content to a pandas dataframe**

# %% [markdown]
# We use pandas to create a dataframe holding the information we gathered from Rotten Tomatoes. This is the gateway to data analysis and data cleaning. From pandas we can export a `.csv` file that can later be cleaned, loaded in various applications and finally used to code our prototype.

# %%
AllStreamingTitles = pd.DataFrame(moviesData, columns=["Title", "Runtime", "Release Date", "IMDB Rating", "Critics Score", "Votes", "Gross"])

# %%
#Previewing 5 random rows from my dataframe
AllStreamingTitles.sample(5)
# Out:
#                   Title  Runtime Release Date IMDB Rating Critics Score  \
# 28        Jurassic Park  127 min       (1993)         8.1            68
# 176      The Karate Kid  126 min       (1984)         7.3            60
# 83               Batman  126 min       (1989)         7.5            69
# 60   The Princess Bride   98 min       (1987)         8.1            77
# 141           True Lies  141 min       (1994)         7.2            63
#
#       Votes      Gross
# 28   925064  402453882
# 176  212236   90815558
# 83   357290  251188924
# 60   415115   30857814
# 141  250422  146282411

# %% [markdown]
# **Step 6: Export dataframe to csv**

# %%
# Check the 'data' subfolder after executing this cell to see the file.
AllStreamingTitles.to_csv('data/unclean/movie_length_to_rating_80_2000.csv', sep=',')

# %% [markdown]
# ### Iterating on page's elements

# %% [markdown]
# What if we need to scrape more than what is visible on the first page? Currently we are getting titles only from the initial screen.
# Instead we want to keep going: our script should be able to proceed down the page and do something everytime new titles need to be loaded. To approach this problem we need to go back to the source website. At the bottom of the page it's possible to spot a yellow "Show More" button, if we click on it new movies are loaded.
#
# **Positive aspects**
# - We have a distinct element, the yellow button with fairly easy interaction
# - We have a stable pattern and everything is happening on one single page, we don't need to touch the page URL
# - We can adopt a similar procedure to the previous one.
#
# **Negative aspects**
# - The page indefinitely loads new content, the button does not change and/or disappear at some point
#
# This calls for a fairly simple strategy. We will modify only one step of our procedure: step 3. Instead of creating a variable with the first page results, we will create a while loop that keeps loading content up to a certain point, while getting all the movies. This particular case does not require that we access individual URLs, for an example of cross-page scraping see the Advanced Dynamic Scraper notebook.

# %% [markdown]
# **Step 1 and 2 stay the same!**

# %% [markdown]
# **Step 3: automate clicking of the "Show More" button**

# %% [markdown]
# Websites generally don't like to be scraped (on some websites it's explicitly forbidden, so be careful). It can happen that if we are interacting with the page too quickly we might get blocked or throttled (slowed down). We will fake interactions with the "Show More" button every 5 seconds to avoid throttle.

# %%
# I am creating a variable holding the number of times I want to click on the 'Show More' button. 
# Alternatively I could code my script to stop when a certain point in data is reached, 
#for example a particular title
pageExpandLimit = 0
# I am also creating a variable to store movie pictures correctly
count = 0
# An empty list to store my webelements
moreMovies = []
# And an empty list that will be filled with my data.
dataList = []

while True:
    # Add 1 to counter so we can artificially stop the loop
    print('I clicked "show more" {0} times'.format(pageExpandLimit))
    pageExpandLimit = pageExpandLimit + 1 
    
    # Taking a screenshot everytime we click on the button (to check where my browser's at)
    # This can be remove if it ends up taking too much space.
    driver.save_screenshot("screenshots/screenshot{0}.png".format(pageExpandLimit))
    
    if pageExpandLimit < 10:
        
        # Generic asleep time to avoid throttle
        time.sleep(5)
        # Find the button element and click on it to keep loading movies
        driver.find_element(By.CLASS_NAME, 'mb-load-btn').click()  
        # Dump all the elements in one list
        moreMovies = driver.find_elements(By.CLASS_NAME, 'mb-movie')
        
    # It will set the condition to False if counter is greater than 10, this will break the while loop
    if pageExpandLimit > 10:
        
        # Before breaking the loop I will go through the data as I did in the example above
        print('started movies collection')
        for movie in moreMovies:
            count = count + 1
            try:
                title = movie.find_element(By.CLASS_NAME, 'movieTitle').text
                rating = movie.find_element(By.CLASS_NAME, 'tMeterIcon').text
                available = movie.find_element(By.CLASS_NAME, 'release-date').text
                image = movie.find_element_by_tag_name('img')
            
                print(count, '/', title)

                source = image.get_attribute("src")

                imgdestination = "data/img_basic/poster-{0}.jpg".format(count)
                urllib.request.urlretrieve(source, imgdestination)

                # Appending data
                dataList.append([title, rating, available, imgdestination])
            except:
                print('an exception occurred for', count)
            
        # Breaking and exiting the loop
        break
# Out:
# I clicked "show more" 0 times
# I clicked "show more" 1 times
# I clicked "show more" 2 times
# I clicked "show more" 3 times
# I clicked "show more" 4 times
# I clicked "show more" 5 times
# I clicked "show more" 6 times
# I clicked "show more" 7 times
# I clicked "show more" 8 times
# I clicked "show more" 9 times
# I clicked "show more" 10 times
# started movies collection
# 1 / Rumble
# /Users/arran/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# 2 / Hurt
# 3 / Mosley
# 4 / Benedetta
# 5 / Last Words
# 6 / Saint-Narcisse
# 7 / Try Harder!
# 8 / Back To The Outback
# 9 / The Scary Of Sixty-First
# 10 / Sensation
# 11 / Red Snow
# 12 / The Novice
# 13 / Even Mice Belong In Heaven
# 14 / The Lost Daughter
# 15 / The Hand Of God (È Stata La Mano Di Dio)
# 16 / Encounter
# 17 / Don'T Look Up
# 18 / The United States Of Insanity
# 19 / The Unforgivable
# 20 / Being The Ricardos
# 21 / The Hating Game
# 22 / Portal Runner
# 23 / Swan Song
# 24 / Mother/Android
# 25 / Project Space 13
# 26 / Joy Womack: The White Swan
# 27 / The Last Son
# 28 / Boxing Day
# 29 / Margrete - Queen Of The North
# 30 / Minnal Murali
# 31 / Harry Potter 20th Anniversary: Return To Hogwarts
# 32 / Beanie Mania
# 33 / Clifford The Big Red Dog
# 34 / Bugs
# 35 / They Say Nothing Stays The Same (Aru Sendo No Hanashi)
# 36 / Broken Law
# 37 / Violet
# 38 / Freeland
# 39 / Gustav Stickley: American Craftsman
# 40 / She Paradise
# 41 / A Gift From Bob
# 42 / Karen Dalton: In My Own Time
# 43 / Night Raiders
# 44 / Captains Of Za'Atari
# 45 / Ma Belle, My Beauty
# 46 / King Richard
# 47 / Clerk
# 48 / The Feast
# 49 / Brian Wilson: Long Promised Road
# 50 / 13 Minutes
# 51 / The Drummer
# 52 / Kurt Vonnegut: Unstuck In Time
# 53 / Zeros And Ones
# 54 / Boiling Point
# 55 / Soulmates
# 56 / Dangerous
# 57 / Motherly
# 58 / One Shot
# 59 / The Last Days Of Capitalism
# 60 / Apex
# 61 / See You Next Christmas
# 62 / Alpha Rift
# 63 / Repeat
# 64 / That Cold Dead Look In Your Eyes
# 65 / Dune
# 66 / The Capote Tapes
# 67 / De Gaulle
# 68 / Beans
# 69 / Keyboard Fantasies
# 70 / The Estate
# 71 / The End Of The Storm
# 72 / Knocking
# 73 / Bergman Island
# 74 / Son Of Monarchs
# 75 / At The Ready
# 76 / Broadcast Signal Intrusion
# 77 / The Spine Of Night
# 78 / The Beta Test
# 79 / Tango Shalom
# 80 / Mark, Mary & Some Other People
# 81 / Ida Red
# 82 / Finding Kendrick Johnson
# 83 / Snakehead
# 84 / Mothers Of The Revolution
# 85 / Joy Ride
# 86 / Warning
# 87 / Runt
# 88 / The Village Detective: A Song Cycle
# 89 / Dashcam
# 90 / Christmas On The Carousel
# 91 / Night At The Eagle Inn
# 92 / Outlier
# 93 / The Deep House
# 94 / Isolation
# 95 / Bigfoot Famous
# 96 / Alice Is Still Dead
# 97 / Needle In A Timestack
# 98 / Halloween Kills
# 99 / Held For Ransom (Ser Du Månen, Daniel)
# 100 / The Many Saints Of Newark
# 101 / In Full Bloom
# 102 / Adventures Of A Mathematician
# 103 / Red Heaven
# 104 / Blizzard Of Souls (The Rifleman) (Dveselu Putenis)
# 105 / The Old Ways
# 106 / The Addams Family 2
# 107 / Sophie Jones
# 108 / Mayday
# 109 / Coming Home In The Dark
# 110 / The Blazing World
# 111 / I'M Your Man
# 112 / Witch Hunt
# 113 / Not Going Quietly
# 114 / The Gig Is Up
# 115 / After We Fell
# 116 / American Insurrection (The Volunteers)
# 117 / Live At Mister Kelly'S
# 118 / Demigod
# 119 / American Night
# 120 / Survive The Game
# 121 / South Of Heaven
# 122 / Pharma Bro
# 123 / Hell Or High Seas
# 124 / Implanted
# 125 / Vengeance Is Mine
# 126 / The Cleaner
# 127 / PTSD: The Walking Wounded
# 128 / Grave Intentions
# 129 / The Nowhere Inn
# 130 / Swimming Out Till The Sea Turns Blue
# 131 / Fully Realized Humans
# 132 / Lone Wolf
# 133 / The Killing Of Kenneth Chamberlain
# 134 / This Is The Year
# 135 / Through The Glass Darkly
# 136 / The Wonderful: Stories From The Space Station
# 137 / Prisoners Of The Ghostland
# 138 / The Auschwitz Report
# 139 / Best Sellers
# 140 / On These Grounds (Spring Valley)
# 141 / Seance
# 142 / East Of The Mountains
# 143 / Last Night In Rozzie
# 144 / All The Streets Are Silent: The Convergence Of Hip Hop And Skateboarding (1987-1997)
# 145 / Bitchin': The Sound And Fury Of Rick James
# 146 / A Dim Valley
# 147 / We Need To Do Something
# 148 / Dating & New York
# 149 / Lady Of The Manor
# 150 / Zone 414
# 151 / The Gateway
# 152 / Yakuza Princess
# 153 / Collection
# 154 / The Influencer
# 155 / Bad Candy
# 156 / Death Drop Gorgeous
# 157 / Another Girl
# 158 / This Is The Night
# 159 / When I'M A Moth
# 160 / The Seer And The Unseen
# 161 / Rare Beasts
# 162 / Really Love
# 163 / The Green Knight
# 164 / Howling Village (Inunaki Mura)
# 165 / PAW Patrol: The Movie
# 166 / PVT CHAT
# 167 / Missing In Brooks County
# 168 / Ellie And Abbie (And Ellie'S Dead Aunt)
# 169 / Barbara Lee: Speaking Truth To Power
# 170 / Cryptozoo
# 171 / Reminiscence
# 172 / Notorious Nick
# 173 / The Colony (Tides)
# 174 / Too Late
# 175 / Demonic
# 176 / No Man Of God
# 177 / Behemoth
# 178 / Last Man Standing: Suge Knight And The Murders Of Biggie & Tupac
# 179 / Habit
# 180 / Blood Conscious
# 181 / The Last Matinee (Red Screening)
# 182 / Baby Money
# 183 / Ted Bundy: American Boogeyman
# 184 / The Mayberry Effect
# 185 / Paper Tiger
# 186 / Karen
# 187 / The Suicide Squad
# 188 / You Will Die At Twenty
# 189 / Rising Wolf (Ascendant)
# 190 / Curiosa
# 191 / Whirlybird
# 192 / The American Sector
# 193 / Pig
# 194 / Enemies Of The State
# 195 / Lorelei
# 196 / John And The Hole
# 197 / The Exchange
# 198 / Materna
# 199 / The Meaning Of Hitler
# 200 / Twist
# 201 / Under The Volcano
# 202 / Infinitum: Subject Unknown
# 203 / Naked Singularity
# 204 / Night Drive
# 205 / American Traitor: The Trial Of Axis Sally
# 206 / The East
# 207 / Crime Story
# 208 / Buckley'S Chance
# 209 / Sparkling: The Story Of Champagne
# 210 / Charming The Hearts Of Men
# 211 / Val
# 212 / Mondo Hollywoodland
# 213 / Queen Of The Beach
# 214 / The Land Of Owls
# 215 / Overrun
# 216 / The Legend Of Tayos
# 217 / The Shattering
# 218 / Rose Plays Julie
# 219 / For Madmen Only
# 220 / Sweat
# 221 / Never Gonna Snow Again
# 222 / Mandibles (Mandibules)
# 223 / Tailgate (Bumperkleef)
# 224 / Meander
# 225 / How It Ends
# 226 / Long Story Short
# 227 / Werewolves Within
# 228 / Kid Candidate
# 229 / The Loneliest Whale: The Search For 52
# 230 / Settlers
# 231 / The House Next Door: Meet The Blacks 2
# 232 / Great White
# 233 / Till Death
# 234 / The Phantom
# 235 / Danny. Legend. God.
# 236 / Marathon
# 237 / The Nest
# 238 / Running Against The Wind
# 239 / Midnight In The Switchgrass
# 240 / Die In A Gunfight
# 241 / Batman: The Long Halloween, Part Two
# 242 / We Intend To Cause Havoc
# 243 / Here After
# 244 / River
# 245 / The Body Fights Back
# 246 / Toofaan
# 247 / The New Bauhaus
# 248 / Ice Guardians
# 249 / Steps
# 250 / Dead Pigs
# 251 / Dream Horse
# 252 / Lydia Lunch: The War Is Never Over
# 253 / My Heart Can'T Beat Unless You Tell It To
# 254 / The Oak Room
# 255 / Stalker
# 256 / The Man Who Sold His Skin
# 257 / Akilla'S Escape
# 258 / Luca
# 259 / My Tender Matador (Tengo Miedo Torero)
# 260 / Say Your Prayers
# 261 / Escape From Extinction
# 262 / Silent Night
# 263 / First Date
# 264 / Censor
# 265 / Batman: The Long Halloween, Part One
# 266 / Gaia
# 267 / Spirit Untamed
# 268 / The Evil Next Door (The Other Side)
# 269 / Forget Everything And Run (F.E.A.R.)
# 270 / A Perfect Enemy
# 271 / Rogue Hostage
# 272 / Death In Texas
# 273 / Hamlet/Horatio
# 274 / Let Us In
# 275 / Lansky
# 276 / Scenes From An Empty Church
# 277 / The Birthday Cake
# 278 / Untitled Horror Movie
# 279 / The God Committee

# %%
print(dataList)
# Out:
# [['Rumble', ' 29%', 'Available Dec 15', 'data/img_basic/poster-1.jpg'], ['Hurt', ' 67%', 'Available Dec 10', 'data/img_basic/poster-2.jpg'], ['Mosley', ' 60%', 'Available Dec 10', 'data/img_basic/poster-3.jpg'], ['Benedetta', ' 85%', 'Available Dec 21', 'data/img_basic/poster-4.jpg'], ['Last Words', ' 33%', 'Available Dec 17', 'data/img_basic/poster-5.jpg'], ['Saint-Narcisse', ' 100%', 'Available Dec 14', 'data/img_basic/poster-6.jpg'], ['Try Harder!', ' 97%', 'Available Dec 24', 'data/img_basic/poster-7.jpg'], ['Back To The Outback', ' 88%', 'Available Dec 10', 'data/img_basic/poster-8.jpg'], ['The Scary Of Sixty-First', ' 56%', 'Available Dec 24', 'data/img_basic/poster-9.jpg'], ['Sensation', ' 17%', 'Available Dec 31', 'data/img_basic/poster-10.jpg'], ['Red Snow', ' 73%', 'Available Dec 28', 'data/img_basic/poster-11.jpg'], ['The Novice', ' 95%', 'Available Dec 17', 'data/img_basic/poster-12.jpg'], ['Even Mice Belong In Heaven', ' 100%', 'Available Dec 10', 'data/img_basic/poster-13.jpg'], ['The Lost Daughter', ' 95%', 'Available Dec 31', 'data/img_basic/poster-14.jpg'], ['The Hand Of God (È Stata La Mano Di Dio)', ' 83%', 'Available Dec 15', 'data/img_basic/poster-15.jpg'], ['Encounter', ' 57%', 'Available Dec 10', 'data/img_basic/poster-16.jpg'], ["Don'T Look Up", ' 56%', 'Available Dec 24', 'data/img_basic/poster-17.jpg'], ['The United States Of Insanity', ' 100%', 'Available Dec 10', 'data/img_basic/poster-18.jpg'], ['The Unforgivable', ' 37%', 'Available Dec 10', 'data/img_basic/poster-19.jpg'], ['Being The Ricardos', ' 69%', 'Available Dec 21', 'data/img_basic/poster-20.jpg'], ['The Hating Game', ' 71%', 'Available Dec 10', 'data/img_basic/poster-21.jpg'], ['Portal Runner', ' 100%', 'Available Dec 10', 'data/img_basic/poster-22.jpg'], ['Swan Song', ' 79%', 'Available Dec 17', 'data/img_basic/poster-23.jpg'], ['Mother/Android', ' 29%', 'Available Dec 17', 'data/img_basic/poster-24.jpg'], ['Project Space 13', ' 80%', 'Available Dec 10', 'data/img_basic/poster-25.jpg'], ['Joy Womack: The White Swan', ' 100%', 'Available Dec 10', 'data/img_basic/poster-26.jpg'], ['The Last Son', ' 25%', 'Available Dec 10', 'data/img_basic/poster-27.jpg'], ['Boxing Day', ' 81%', 'Available Dec 17', 'data/img_basic/poster-28.jpg'], ['Margrete - Queen Of The North', ' 90%', 'Available Dec 17', 'data/img_basic/poster-29.jpg'], ['Minnal Murali', ' 60%', 'Available Dec 24', 'data/img_basic/poster-30.jpg'], ['Harry Potter 20th Anniversary: Return To Hogwarts', ' 94%', 'Available Jan 1', 'data/img_basic/poster-31.jpg'], ['Beanie Mania', ' 100%', 'Available Dec 23', 'data/img_basic/poster-32.jpg'], ['Clifford The Big Red Dog', ' 57%', 'Available Nov 10', 'data/img_basic/poster-33.jpg'], ['Bugs', ' 88%', 'Available Nov 16', 'data/img_basic/poster-34.jpg'], ['They Say Nothing Stays The Same (Aru Sendo No Hanashi)', ' 100%', 'Available Nov 12', 'data/img_basic/poster-35.jpg'], ['Broken Law', ' 100%', 'Available Nov 16', 'data/img_basic/poster-36.jpg'], ['Violet', ' 82%', 'Available Nov 9', 'data/img_basic/poster-37.jpg'], ['Freeland', ' 100%', 'Available Nov 19', 'data/img_basic/poster-38.jpg'], ['Gustav Stickley: American Craftsman', ' 71%', 'Available Nov 15', 'data/img_basic/poster-39.jpg'], ['She Paradise', ' 88%', 'Available Nov 19', 'data/img_basic/poster-40.jpg'], ['A Gift From Bob', ' 79%', 'Available Nov 9', 'data/img_basic/poster-41.jpg'], ['Karen Dalton: In My Own Time', ' 100%', 'Available Nov 16', 'data/img_basic/poster-42.jpg'], ['Night Raiders', ' 84%', 'Available Nov 12', 'data/img_basic/poster-43.jpg'], ["Captains Of Za'Atari", ' 94%', 'Available Nov 19', 'data/img_basic/poster-44.jpg'], ['Ma Belle, My Beauty', ' 77%', 'Available Nov 23', 'data/img_basic/poster-45.jpg'], ['King Richard', ' 91%', 'Available Nov 19', 'data/img_basic/poster-46.jpg'], ['Clerk', ' 80%', 'Available Nov 23', 'data/img_basic/poster-47.jpg'], ['The Feast', ' 81%', 'Available Nov 19', 'data/img_basic/poster-48.jpg'], ['Brian Wilson: Long Promised Road', ' 94%' ...

# %%
MoreStreamingTitles = pd.DataFrame(dataList, columns=["title", "rating", "available", "img"])

# %%
MoreStreamingTitles.sample(5)
# Out:
#                              title rating         available  \
# 83       Mothers Of The Revolution   100%  Available Oct 19
# 17   The United States Of Insanity   100%  Available Dec 10
# 151                Yakuza Princess    35%   Available Sep 3
# 185                          Karen    17%   Available Sep 3
# 53                   Boiling Point    98%  Available Nov 23
#
#                                img
# 83    data/img_basic/poster-84.jpg
# 17    data/img_basic/poster-18.jpg
# 151  data/img_basic/poster-152.jpg
# 185  data/img_basic/poster-186.jpg
# 53    data/img_basic/poster-54.jpg

# %%
MoreStreamingTitles.to_csv('data/titlesDataRaw_extended.csv', sep=',')

# %% [markdown]
# **Steps 4, 5 and 6 are identical to the "one page simple scraping" example**

# %%
#Ultimately, once we got everything we were interested in, we need to quit our WebDriver to avoid sessions piling up
driver.quit()

# %% [markdown]
# ### Conclusion
#
# Each website is different, therefore scraping is often a tailored activity that requires some coding and strategizing effort. This tutorial presented some simple features and a couple of useful patterns if you need to scrape a relatively contained amount of data. There are more complex and articulated tasks that require more savviness, time and computing effort. One example are social media. For special or recurring cases there's a useful collection of tools that can be found [here](https://wiki.digitalmethods.net/Dmi/ToolDatabase).

# %% [markdown]
# ### References
#
# 1. Guide to Selenium basic functions for scraping: https://www.scrapingbee.com/blog/selenium-python/
# 2. Including WebDriver location in MacOS System Path: https://www.kenst.com/2015/03/including-the-chromedriver-location-in-macos-system-path/
# 3. Data Science Skills Set: https://francesco-ai.medium.com/data-science-skills-list-9f38863adab5
# 4. DMI Tools Database: https://wiki.digitalmethods.net/Dmi/ToolDatabase
